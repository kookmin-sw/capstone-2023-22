# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/fulldata_07_24_05_P.csv",dtype=object, encoding='cp949')
df
# Out:
#             번호 개방서비스명    개방서비스아이디 개방자치단체코드                    관리번호  \
# 0            1  휴게음식점  07_24_05_P  4040000  4040000-104-2022-00116
# 1            2  휴게음식점  07_24_05_P  3940000  3950000-104-2022-00116
# 2            3  휴게음식점  07_24_05_P  3670000  3670000-104-2022-00149
# 3            4  휴게음식점  07_24_05_P  4670000  4670000-104-2022-00076
# 4            5  휴게음식점  07_24_05_P  3150000  3150000-104-2022-00138
# ...        ...    ...         ...      ...                     ...
# 524445  524446  휴게음식점  07_24_05_P  3610000  3610000-104-2018-00018
# 524446  524447  휴게음식점  07_24_05_P  3610000  3610000-104-2018-00027
# 524447  524448  휴게음식점  07_24_05_P  3610000  3610000-104-2018-00031
# 524448  524449  휴게음식점  07_24_05_P  3610000  3610000-104-2017-00085
# 524449  524450  휴게음식점  07_24_05_P  3600000  3600000-104-2010-00022
#
#              인허가일자 인허가취소일자 영업상태구분코드  영업상태명 상세영업상태코드  ... 공장생산직직원수 건물소유구분명  \
# 0       2022-05-17     NaN       03     폐업       02  ...        0     NaN
# ...

# %%
df.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수',
#        '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수', '건물소유구분명', '보증액', '월세액',
#        '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지', 'Unnamed: 47'],
#       dtype='object')

# %%
dat_opened = df[df['영업상태명'] == '영업/정상']
dat_opened.describe
# Out:
# <bound method NDFrame.describe of             번호 개방서비스명    개방서비스아이디 개방자치단체코드                    관리번호  \
# 324986  324987  휴게음식점  07_24_05_P  3200000  3200000-104-2022-00087
# 324987  324988  휴게음식점  07_24_05_P  3200000  3200000-104-2022-00086
# 324988  324989  휴게음식점  07_24_05_P  4040000  4040000-104-2022-00115
# 324989  324990  휴게음식점  07_24_05_P  4040000  4040000-104-2022-00114
# 324990  324991  휴게음식점  07_24_05_P  4040000  4040000-104-2022-00113
# ...        ...    ...         ...      ...                     ...
# 524445  524446  휴게음식점  07_24_05_P  3610000  3610000-104-2018-00018
# 524446  524447  휴게음식점  07_24_05_P  3610000  3610000-104-2018-00027
# 524447  524448  휴게음식점  07_24_05_P  3610000  3610000-104-2018-00031
# 524448  524449  휴게음식점  07_24_05_P  3610000  3610000-104-2017-00085
# 524449  524450  휴게음식점  07_24_05_P  3600000  3600000-104-2010-00022
#
#              인허가일자 인허가취소일자 영업상태구분코드  영업상태명 상세영업상태코드  ... 공장생산직직원수 건물소유구분명  \
# ...

# %%
dat_opened.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199464 entries, 324986 to 524449
# Data columns (total 48 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   번호           199464 non-null  object
#  1   개방서비스명       199464 non-null  object
#  2   개방서비스아이디     199464 non-null  object
#  3   개방자치단체코드     199464 non-null  object
#  4   관리번호         199464 non-null  object
#  5   인허가일자        199464 non-null  object
#  6   인허가취소일자      0 non-null       object
#  7   영업상태구분코드     199464 non-null  object
#  8   영업상태명        199464 non-null  object
#  9   상세영업상태코드     199464 non-null  object
#  10  상세영업상태명      199464 non-null  object
#  11  폐업일자         0 non-null       object
#  12  휴업시작일자       0 non-null       object
#  13  휴업종료일자       0 non-null       object
#  14  재개업일자        0 non-null       object
#  15  소재지전화        67213 non-null   object
#  16  소재지면적        193134 non-null  object
#  17  소재지우편번호      191422 non-null  object
# ...

# %%
dat_opened_in_seoul = dat_opened.loc[dat_opened['도로명전체주소'].str.contains('서울특별시', na=False),['사업장명', '영업상태명','도로명전체주소', '좌표정보(x)', '좌표정보(y)','위생업태명','시설총규모']]
dat_opened_in_seoul
# Out:
#                            사업장명  영업상태명  \
# 324986                      빙동댕  영업/정상
# 324987                 씨유 관악은천점  영업/정상
# 324997                       쮸샌  영업/정상
# 325008               씨유 화곡트윈캐슬점  영업/정상
# 325016            탐앤탐스 종로 한올타워점  영업/정상
# ...                         ...    ...
# 514799               백남옥 달인 손만두  영업/정상
# 514853               원기정 디큐브시티점  영업/정상
# 514984  happy cake shop(해피케이크샵)  영업/정상
# 516569                   카페it수다  영업/정상
# 516570            쥬씨(신반포 반원상가점)  영업/정상
#
#                                                   도로명전체주소           좌표정보(x)  \
# 324986              서울특별시 관악구 봉천로 274, 제가동 제1층 제01호 (신림동)  193848.560915502
# 324987                       서울특별시 관악구 은천로25길 7, 1층 (봉천동)  195414.929995391
# 324997                     서울특별시 관악구 쑥고개로11길 35, 1층 (봉천동)  194832.123820743
# 325008       서울특별시 강서구 초록마을로 71, 1층 101호 (화곡동, 우성트윈캐슬아파트)  186728.272021831
# 325016                      서울특별시 종로구 종로 96, 1, 2층 (종로2가)  198892.023011278
# ...

# %%
dat_opened_in_seoul['위생업태명'].unique()
# Out:
# array(['커피숍', '편의점', '일반조리판매', '기타 휴게음식점', '아이스크림', '패스트푸드', '푸드트럭', '다방',
#        '떡카페', '백화점', '전통찻집', '키즈카페', '철도역구내', '고속도로', '관광호텔', '과자점',
#        '유원지', '극장', '호프/통닭', '공항'], dtype=object)

# %%
dat_opened_in_seoul_only_coffee = dat_opened_in_seoul[df['위생업태명'].isin(['커피숍','떡카페', '유원지','극장','공항'])]
dat_opened_in_seoul_only_coffee
# Out:
# <ipython-input-12-7d48f2c15113>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dat_opened_in_seoul_only_coffee = dat_opened_in_seoul[df['위생업태명'].isin(['커피숍','떡카페', '유원지','극장','공항'])]
#                   사업장명  영업상태명                                         도로명전체주소  \
# 324986             빙동댕  영업/정상           서울특별시 관악구 봉천로 274, 제가동 제1층 제01호 (신림동)
# 325016   탐앤탐스 종로 한올타워점  영업/정상                   서울특별시 종로구 종로 96, 1, 2층 (종로2가)
# 325031        웨스트커프하우스  영업/정상                서울특별시 강남구 도산대로54길 10, 지상1층 (논현동)
# 325032   머그샷(Mug,shot)  영업/정상           서울특별시 강남구 선릉로64길 8-2, 지상1층 101호 (대치동)
# 325046           디저트39  영업/정상                    서울특별시 관악구 봉천로7길 41, 1층 (봉천동)
# ...                ...    ...                                             ...
# 514604       굿애프터눈 합정점  영업/정상  서울특별시 마포구 월드컵로3길 14 (합정동, 마포한강2차푸르지오상업시설 120호)
# 514606       보노보나마포합정점  영업/정상       서울특별시 마포구 월드컵로3길 14 (합정동, 한강푸르지오지하1층142호)
# ...

# %%
dat_opened_in_seoul_only_coffee.to_csv('/content/drive/MyDrive/team-andes/data_seoul_coffee_utf8.csv',sep=',',encoding='utf-8')
